# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1




# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1       
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Curent Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | agudos
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | zhigansk
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | pionki
# Processing Record 9 of Set 1 | opuwo
# Processing Record 10 of Set 1 | bosaso
# Processing Record 11 of Set 1 | port shepstone
# Processing Record 12 of Set 1 | gigmoto
# Processing Record 13 of Set 1 | guerrero negro
# Processing Record 14 of Set 1 | te anau
# Processing Record 15 of Set 1 | bengkulu
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | talnakh
# Processing Record 19 of Set 1 | camana
# Processing Record 20 of Set 1 | celestun
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | houston
# Processing Record 27 of Set 1 | otaru
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | verkhnevilyuysk
# Processing Record 30 of Set 1 | namibe
# Processing Record 31 of Set 1 | kikwit
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | tandalti
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | narsaq
# Processing Record 36 of Set 1 | nome
# Processing Record 37 of Set 1 | fairbanks
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | naze
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | jinchang
# Processing Record 43 of Set 1 | sherbakul
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | kruisfontein
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | bonavista
# Processing Record 49 of Set 1 | zarya
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | vieste
# Processing Record 4 of Set 2 | angoche
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | andevoranto
# City not found. Skipping...
# Processing Record 7 of Set 2 | keighley
# Processing Record 8 of Set 2 | hami
# Processing Record 9 of Set 2 | ordzhonikidze
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | cristalina
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | praia da vitoria
# Processing Record 15 of Set 2 | port hardy
# Processing Record 16 of Set 2 | puerto del rosario
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | mahanoro
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | berlevag
# Processing Record 22 of Set 2 | puerto baquerizo moreno
# Processing Record 23 of Set 2 | cabo san lucas
# Processing Record 24 of Set 2 | ban nahin
# Processing Record 25 of Set 2 | jalu
# Processing Record 26 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 27 of Set 2 | bilma
# Processing Record 28 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | teguldet
# Processing Record 31 of Set 2 | saint-louis
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | chabahar
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | longyearbyen
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | fare
# Processing Record 39 of Set 2 | luderitz
# Processing Record 40 of Set 2 | adrar
# Processing Record 41 of Set 2 | katsuura
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | mirnyy
# Processing Record 45 of Set 2 | lorengau
# Processing Record 46 of Set 2 | mercedes
# Processing Record 47 of Set 2 | hobart
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | grindavik
# Processing Record 50 of Set 2 | staraya sunzha
# Processing Record 1 of Set 3 | venafro
# Processing Record 2 of Set 3 | trairi
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | alofi
# Processing Record 5 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 3 | yar-sale
# Processing Record 7 of Set 3 | lazaro cardenas
# Processing Record 8 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 9 of Set 3 | antigonish
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 3 | ovsyanka
# Processing Record 13 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 14 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 3 | severo-kurilsk
# Processing Record 16 of Set 3 | loiza
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | carutapera
# Processing Record 19 of Set 3 | awbari
# Processing Record 20 of Set 3 | zelenoborskiy
# Processing Record 21 of Set 3 | arlit
# Processing Record 22 of Set 3 | auki
# Processing Record 23 of Set 3 | podosinovets
# Processing Record 24 of Set 3 | homer
# Processing Record 25 of Set 3 | san joaquin
# Processing Record 26 of Set 3 | san juan
# Processing Record 27 of Set 3 | saldanha
# Processing Record 28 of Set 3 | hasaki
# Processing Record 29 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 3 | paragominas
# Processing Record 31 of Set 3 | juneau
# Processing Record 32 of Set 3 | villa vazquez
# City not found. Skipping...
# Processing Record 33 of Set 3 | baykit
# Processing Record 34 of Set 3 | severnoye
# Processing Record 35 of Set 3 | talaya
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | cape town
# Processing Record 39 of Set 3 | saskylakh
# Processing Record 40 of Set 3 | labuhan
# Processing Record 41 of Set 3 | almaznyy
# Processing Record 42 of Set 3 | lazarev
# Processing Record 43 of Set 3 | puerto pinasco
# City not found. Skipping...
# Processing Record 44 of Set 3 | phoenixville
# Processing Record 45 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 3 | clyde river
# Processing Record 47 of Set 3 | rawson
# Processing Record 48 of Set 3 | solnechnyy
# Processing Record 49 of Set 3 | dubrovnik
# Processing Record 50 of Set 3 | ilulissat
# Processing Record 1 of Set 4 | hofn
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | birjand
# Processing Record 5 of Set 4 | alice springs
# Processing Record 6 of Set 4 | kahului
# Processing Record 7 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | iralaya
# Processing Record 12 of Set 4 | svetlaya
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | lavrentiya
# Processing Record 15 of Set 4 | norman wells
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | dickinson
# Processing Record 18 of Set 4 | stepnyak
# Processing Record 19 of Set 4 | marawi
# Processing Record 20 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 4 | karasburg
# Processing Record 22 of Set 4 | dharchula
# Processing Record 23 of Set 4 | jumla
# Processing Record 24 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 4 | oistins
# Processing Record 26 of Set 4 | kelo
# Processing Record 27 of Set 4 | lata
# Processing Record 28 of Set 4 | porto nacional
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | avarua
# Processing Record 31 of Set 4 | mineiros
# Processing Record 32 of Set 4 | mikkeli
# Processing Record 33 of Set 4 | burns lake
# Processing Record 34 of Set 4 | codrington
# Processing Record 35 of Set 4 | petropavl
# Processing Record 36 of Set 4 | ullapool
# Processing Record 37 of Set 4 | ayan
# Processing Record 38 of Set 4 | skibbereen
# Processing Record 39 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 4 | san isidro
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | kiunga
# Processing Record 43 of Set 4 | taoudenni
# Processing Record 44 of Set 4 | baruun-urt
# Processing Record 45 of Set 4 | hamilton
# Processing Record 46 of Set 4 | sinjah
# City not found. Skipping...
# Processing Record 47 of Set 4 | manzanillo
# Processing Record 48 of Set 4 | klaksvik
# Processing Record 49 of Set 4 | sisimiut
# Processing Record 50 of Set 4 | pevek
# Processing Record 1 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 5 | shelburne
# Processing Record 3 of Set 5 | chuy
# Processing Record 4 of Set 5 | grajau
# Processing Record 5 of Set 5 | vila franca do campo
# Processing Record 6 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 5 | las cruces
# Processing Record 8 of Set 5 | maralal
# Processing Record 9 of Set 5 | sobolevo
# Processing Record 10 of Set 5 | nalut
# Processing Record 11 of Set 5 | worland
# Processing Record 12 of Set 5 | airai
# Processing Record 13 of Set 5 | bartlesville
# Processing Record 14 of Set 5 | lebu
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | hilo
# Processing Record 17 of Set 5 | biltine
# Processing Record 18 of Set 5 | griffith
# Processing Record 19 of Set 5 | bereda
# Processing Record 20 of Set 5 | waddan
# Processing Record 21 of Set 5 | kalat
# Processing Record 22 of Set 5 | samarai
# Processing Record 23 of Set 5 | sitka
# Processing Record 24 of Set 5 | bethel
# Processing Record 25 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 5 | deputatskiy
# Processing Record 27 of Set 5 | aklavik
# Processing Record 28 of Set 5 | mweka
# Processing Record 29 of Set 5 | black river
# Processing Record 30 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 5 | gainesville
# Processing Record 33 of Set 5 | zhanaozen
# Processing Record 34 of Set 5 | ulundi
# Processing Record 35 of Set 5 | carnarvon
# Processing Record 36 of Set 5 | ust-kan
# Processing Record 37 of Set 5 | rohri
# Processing Record 38 of Set 5 | sydney
# Processing Record 39 of Set 5 | saint george
# Processing Record 40 of Set 5 | waitati
# Processing Record 41 of Set 5 | havre
# Processing Record 42 of Set 5 | nunoa
# Processing Record 43 of Set 5 | cayenne
# Processing Record 44 of Set 5 | ostrovnoy
# Processing Record 45 of Set 5 | laguna
# Processing Record 46 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 47 of Set 5 | lianzhou
# Processing Record 48 of Set 5 | atar
# Processing Record 49 of Set 5 | mokhsogollokh
# Processing Record 50 of Set 5 | senneterre
# Processing Record 1 of Set 6 | kirakira
# Processing Record 2 of Set 6 | porirua
# Processing Record 3 of Set 6 | tateyama
# Processing Record 4 of Set 6 | dumbrava
# Processing Record 5 of Set 6 | hesla
# Processing Record 6 of Set 6 | buala
# Processing Record 7 of Set 6 | ahipara
# Processing Record 8 of Set 6 | sabang
# Processing Record 9 of Set 6 | esperance
# Processing Record 10 of Set 6 | grand gaube
# Processing Record 11 of Set 6 | bom jesus
# Processing Record 12 of Set 6 | fortuna
# Processing Record 13 of Set 6 | bondo
# Processing Record 14 of Set 6 | yokadouma
# Processing Record 15 of Set 6 | miercurea sibiului
# Processing Record 16 of Set 6 | iquique
# Processing Record 17 of Set 6 | zeya
# Processing Record 18 of Set 6 | port-gentil
# Processing Record 19 of Set 6 | glace bay
# Processing Record 20 of Set 6 | sterling
# Processing Record 21 of Set 6 | aksarka
# Processing Record 22 of Set 6 | wilkie
# Processing Record 23 of Set 6 | upernavik
# Processing Record 24 of Set 6 | general pico
# Processing Record 25 of Set 6 | chumikan
# Processing Record 26 of Set 6 | mitsamiouli
# Processing Record 27 of Set 6 | acapulco
# Processing Record 28 of Set 6 | karaman
# Processing Record 29 of Set 6 | bandarbeyla
# Processing Record 30 of Set 6 | nouadhibou
# Processing Record 31 of Set 6 | westport
# Processing Record 32 of Set 6 | moindou
# Processing Record 33 of Set 6 | komatipoort
# Processing Record 34 of Set 6 | vanavara
# Processing Record 35 of Set 6 | touros
# Processing Record 36 of Set 6 | okhotsk
# Processing Record 37 of Set 6 | eganville
# Processing Record 38 of Set 6 | sao jose da coroa grande
# Processing Record 39 of Set 6 | torbay
# Processing Record 40 of Set 6 | nikolskoye
# Processing Record 41 of Set 6 | west bay
# Processing Record 42 of Set 6 | makakilo city
# Processing Record 43 of Set 6 | tomatlan
# Processing Record 44 of Set 6 | burica
# City not found. Skipping...
# Processing Record 45 of Set 6 | andenes
# Processing Record 46 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 6 | krasnogvardeyets
# Processing Record 48 of Set 6 | slonim
# Processing Record 49 of Set 6 | kedarnath
# City not found. Skipping...
# Processing Record 50 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 7 | srednekolymsk
# Processing Record 2 of Set 7 | gizo
# Processing Record 3 of Set 7 | mataram
# Processing Record 4 of Set 7 | necochea
# Processing Record 5 of Set 7 | tura
# Processing Record 6 of Set 7 | lesogorsk
# Processing Record 7 of Set 7 | pathein
# Processing Record 8 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 7 | iguape
# Processing Record 10 of Set 7 | kirkenes
# Processing Record 11 of Set 7 | takestan
# Processing Record 12 of Set 7 | lompoc
# Processing Record 13 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 7 | asosa
# Processing Record 15 of Set 7 | bolshiye uki
# City not found. Skipping...
# Processing Record 16 of Set 7 | peace river
# Processing Record 17 of Set 7 | berezniki
# Processing Record 18 of Set 7 | buenos aires
# Processing Record 19 of Set 7 | eyl
# Processing Record 20 of Set 7 | taloqan
# Processing Record 21 of Set 7 | nador
# Processing Record 22 of Set 7 | khani
# Processing Record 23 of Set 7 | cap-aux-meules
# Processing Record 24 of Set 7 | haines junction
# Processing Record 25 of Set 7 | lingao
# Processing Record 26 of Set 7 | soissons
# Processing Record 27 of Set 7 | tinskoy
# Processing Record 28 of Set 7 | oum hadjer
# Processing Record 29 of Set 7 | sri aman
# Processing Record 30 of Set 7 | saint-augustin
# Processing Record 31 of Set 7 | rabkavi
# Processing Record 32 of Set 7 | nueva loja
# Processing Record 33 of Set 7 | sovetskiy
# Processing Record 34 of Set 7 | katobu
# Processing Record 35 of Set 7 | bisira
# Processing Record 36 of Set 7 | lamu
# Processing Record 37 of Set 7 | chapais
# Processing Record 38 of Set 7 | belyy yar
# Processing Record 39 of Set 7 | wattegama
# Processing Record 40 of Set 7 | eirunepe
# Processing Record 41 of Set 7 | mocuba
# Processing Record 42 of Set 7 | vinh
# Processing Record 43 of Set 7 | phan thiet
# Processing Record 44 of Set 7 | vilhena
# Processing Record 45 of Set 7 | barranquilla
# Processing Record 46 of Set 7 | nanortalik
# Processing Record 47 of Set 7 | nagato
# Processing Record 48 of Set 7 | sawankhalok
# Processing Record 49 of Set 7 | pangai
# Processing Record 50 of Set 7 | ptichye
# Processing Record 1 of Set 8 | la gaulette
# City not found. Skipping...
# Processing Record 2 of Set 8 | kuryk
# Processing Record 3 of Set 8 | yumaguzino
# Processing Record 4 of Set 8 | zhezkazgan
# Processing Record 5 of Set 8 | kidal
# Processing Record 6 of Set 8 | bonthe
# Processing Record 7 of Set 8 | dingle
# Processing Record 8 of Set 8 | nyagan
# Processing Record 9 of Set 8 | sosua
# Processing Record 10 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 11 of Set 8 | constitucion
# Processing Record 12 of Set 8 | mus
# Processing Record 13 of Set 8 | martapura
# Processing Record 14 of Set 8 | pinsk
# Processing Record 15 of Set 8 | shimoda
# Processing Record 16 of Set 8 | barcelos
# Processing Record 17 of Set 8 | goderich
# Processing Record 18 of Set 8 | paramonga
# Processing Record 19 of Set 8 | barra patuca
# Processing Record 20 of Set 8 | quatre cocos
# Processing Record 21 of Set 8 | kommunisticheskiy
# Processing Record 22 of Set 8 | turukhansk
# Processing Record 23 of Set 8 | oranjemund
# Processing Record 24 of Set 8 | le pont-de-claix
# Processing Record 25 of Set 8 | lebanon
# Processing Record 26 of Set 8 | molango
# Processing Record 27 of Set 8 | ayagoz
# Processing Record 28 of Set 8 | isangel
# Processing Record 29 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 8 | akdepe
# Processing Record 31 of Set 8 | faanui
# Processing Record 32 of Set 8 | atambua
# Processing Record 33 of Set 8 | veraval
# Processing Record 34 of Set 8 | kaset sombun
# Processing Record 35 of Set 8 | walvis bay
# Processing Record 36 of Set 8 | sarkikaraagac
# Processing Record 37 of Set 8 | port hedland
# Processing Record 38 of Set 8 | bacolod
# Processing Record 39 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 8 | devonport
# Processing Record 41 of Set 8 | west wendover
# Processing Record 42 of Set 8 | gerash
# Processing Record 43 of Set 8 | marsaxlokk
# Processing Record 44 of Set 8 | palana
# Processing Record 45 of Set 8 | vao
# Processing Record 46 of Set 8 | tamiahua
# Processing Record 47 of Set 8 | kerman
# Processing Record 48 of Set 8 | charagua
# Processing Record 49 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 8 | bay roberts
# Processing Record 1 of Set 9 | komsomolskiy
# Processing Record 2 of Set 9 | kalmunai
# Processing Record 3 of Set 9 | bafang
# Processing Record 4 of Set 9 | san quintin
# Processing Record 5 of Set 9 | salalah
# Processing Record 6 of Set 9 | mareeba
# Processing Record 7 of Set 9 | broken hill
# Processing Record 8 of Set 9 | arman
# Processing Record 9 of Set 9 | tunduma
# Processing Record 10 of Set 9 | vung tau
# Processing Record 11 of Set 9 | yumen
# Processing Record 12 of Set 9 | buluang
# Processing Record 13 of Set 9 | whitehorse
# Processing Record 14 of Set 9 | colwyn bay
# Processing Record 15 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 16 of Set 9 | tuatapere
# Processing Record 17 of Set 9 | ozu
# Processing Record 18 of Set 9 | waseca
# Processing Record 19 of Set 9 | flinders
# Processing Record 20 of Set 9 | muros
# Processing Record 21 of Set 9 | gumrak
# Processing Record 22 of Set 9 | geraldton
# Processing Record 23 of Set 9 | sinegorye
# Processing Record 24 of Set 9 | morag
# Processing Record 25 of Set 9 | prince rupert
# Processing Record 26 of Set 9 | savannakhet
# Processing Record 27 of Set 9 | lamar
# Processing Record 28 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 29 of Set 9 | ossora
# Processing Record 30 of Set 9 | pangnirtung
# Processing Record 31 of Set 9 | miraflores
# Processing Record 32 of Set 9 | meulaboh
# Processing Record 33 of Set 9 | sol-iletsk
# Processing Record 34 of Set 9 | xining
# Processing Record 35 of Set 9 | wakkanai
# Processing Record 36 of Set 9 | taltal
# Processing Record 37 of Set 9 | limoges
# Processing Record 38 of Set 9 | ca mau
# Processing Record 39 of Set 9 | olafsvik
# Processing Record 40 of Set 9 | dingzhou
# Processing Record 41 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 9 | sembe
# Processing Record 43 of Set 9 | tiznit
# Processing Record 44 of Set 9 | uyuni
# Processing Record 45 of Set 9 | yazoo city
# Processing Record 46 of Set 9 | kenai
# Processing Record 47 of Set 9 | katha
# City not found. Skipping...
# Processing Record 48 of Set 9 | tabuk
# Processing Record 49 of Set 9 | virginia beach
# Processing Record 50 of Set 9 | kano
# Processing Record 1 of Set 10 | belmonte
# Processing Record 2 of Set 10 | beringovskiy
# Processing Record 3 of Set 10 | mana
# Processing Record 4 of Set 10 | hirara
# Processing Record 5 of Set 10 | ramos arizpe
# Processing Record 6 of Set 10 | jardim
# Processing Record 7 of Set 10 | vila velha
# Processing Record 8 of Set 10 | fort frances
# Processing Record 9 of Set 10 | yaan
# Processing Record 10 of Set 10 | coahuayana
# Processing Record 11 of Set 10 | stornoway
# Processing Record 12 of Set 10 | ketchikan
# Processing Record 13 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 10 | avera
# Processing Record 15 of Set 10 | ewa beach
# Processing Record 16 of Set 10 | yerbogachen
# Processing Record 17 of Set 10 | kudahuvadhoo
# Processing Record 18 of Set 10 | ati
# Processing Record 19 of Set 10 | vardo
# Processing Record 20 of Set 10 | kayes
# Processing Record 21 of Set 10 | ha tinh
# Processing Record 22 of Set 10 | padang
# Processing Record 23 of Set 10 | pemangkat
# Processing Record 24 of Set 10 | cap malheureux
# Processing Record 25 of Set 10 | ouallam
# Processing Record 26 of Set 10 | humen
# Processing Record 27 of Set 10 | ostuacan
# Processing Record 28 of Set 10 | minas
# Processing Record 29 of Set 10 | ilebo
# Processing Record 30 of Set 10 | prudentopolis
# Processing Record 31 of Set 10 | mehamn
# Processing Record 32 of Set 10 | prainha
# Processing Record 33 of Set 10 | vostok
# Processing Record 34 of Set 10 | bathsheba
# Processing Record 35 of Set 10 | podporozhye
# Processing Record 36 of Set 10 | wa
# City not found. Skipping...
# Processing Record 37 of Set 10 | tilichiki
# Processing Record 38 of Set 10 | mogadishu
# Processing Record 39 of Set 10 | souillac
# Processing Record 40 of Set 10 | pallipattu
# Processing Record 41 of Set 10 | san patricio
# Processing Record 42 of Set 10 | olavarria
# Processing Record 43 of Set 10 | roma
# Processing Record 44 of Set 10 | klyuchi
# Processing Record 45 of Set 10 | riverton
# Processing Record 46 of Set 10 | ocos
# Processing Record 47 of Set 10 | ippy
# Processing Record 48 of Set 10 | basco
# Processing Record 49 of Set 10 | belousovka
# Processing Record 50 of Set 10 | khasan
# Processing Record 1 of Set 11 | fuxin
# Processing Record 2 of Set 11 | anacortes
# Processing Record 3 of Set 11 | payyannur
# Processing Record 4 of Set 11 | zhicheng
# Processing Record 5 of Set 11 | balboa
# Processing Record 6 of Set 11 | oussouye
# Processing Record 7 of Set 11 | los llanos de aridane
# Processing Record 8 of Set 11 | port blair
# Processing Record 9 of Set 11 | eseka
# Processing Record 10 of Set 11 | cubuk
# Processing Record 11 of Set 11 | mnogovershinnyy
# Processing Record 12 of Set 11 | pangody
# Processing Record 13 of Set 11 | havelock
# Processing Record 14 of Set 11 | mudgee
# Processing Record 15 of Set 11 | risor
# Processing Record 16 of Set 11 | kotma
# Processing Record 17 of Set 11 | luang prabang
# Processing Record 18 of Set 11 | faya
# Processing Record 19 of Set 11 | biloela
# Processing Record 20 of Set 11 | iquitos
# Processing Record 21 of Set 11 | mersing
# Processing Record 22 of Set 11 | micheweni
# Processing Record 23 of Set 11 | kutum
# Processing Record 24 of Set 11 | hallingby
# City not found. Skipping...
# Processing Record 25 of Set 11 | santa vitoria do palmar
# Processing Record 26 of Set 11 | bodden town
# Processing Record 27 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 28 of Set 11 | churapcha
# Processing Record 29 of Set 11 | novyy urengoy
# Processing Record 30 of Set 11 | mwanza
# Processing Record 31 of Set 11 | bourail
# Processing Record 32 of Set 11 | vanimo
# Processing Record 33 of Set 11 | seoul
# Processing Record 34 of Set 11 | agutaya
# Processing Record 35 of Set 11 | anito
# Processing Record 36 of Set 11 | kita
# Processing Record 37 of Set 11 | tecpan
# Processing Record 38 of Set 11 | sibolga
# Processing Record 39 of Set 11 | maroantsetra
# Processing Record 40 of Set 11 | iowa city
# Processing Record 41 of Set 11 | santa ana
# Processing Record 42 of Set 11 | fort nelson
# Processing Record 43 of Set 11 | santa rosalia
# Processing Record 44 of Set 11 | porto novo
# Processing Record 45 of Set 11 | moose factory
# Processing Record 46 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 11 | malinyi
# Processing Record 48 of Set 11 | tocopilla
# Processing Record 49 of Set 11 | pacific grove
# Processing Record 50 of Set 11 | trinidad
# Processing Record 1 of Set 12 | san vicente
# Processing Record 2 of Set 12 | mvomero
# Processing Record 3 of Set 12 | qaqortoq
# Processing Record 4 of Set 12 | ancud
# Processing Record 5 of Set 12 | coihaique
# Processing Record 6 of Set 12 | poum
# Processing Record 7 of Set 12 | port macquarie
# Processing Record 8 of Set 12 | hanyang
# Processing Record 9 of Set 12 | machilipatnam
# Processing Record 10 of Set 12 | novobirilyussy
# Processing Record 11 of Set 12 | chokwe
# Processing Record 12 of Set 12 | batagay
# Processing Record 13 of Set 12 | nanaimo
# Processing Record 14 of Set 12 | roald
# Processing Record 15 of Set 12 | tautira
# Processing Record 16 of Set 12 | tual
# Processing Record 17 of Set 12 | chiriqui grande
# Processing Record 18 of Set 12 | staraya mayna
# Processing Record 19 of Set 12 | kargasok
# Processing Record 20 of Set 12 | the valley
# Processing Record 21 of Set 12 | great falls
# Processing Record 22 of Set 12 | east wenatchee bench
# Processing Record 23 of Set 12 | stillwater
# Processing Record 24 of Set 12 | jacqueville
# Processing Record 25 of Set 12 | vestmanna
# Processing Record 26 of Set 12 | sao felix do xingu
# Processing Record 27 of Set 12 | cockburn town
# Processing Record 28 of Set 12 | mahon
# Processing Record 29 of Set 12 | shkotovo-26
# City not found. Skipping...
# Processing Record 30 of Set 12 | banjar
# Processing Record 31 of Set 12 | zatoka
# Processing Record 32 of Set 12 | luanda
# Processing Record 33 of Set 12 | arcachon
# Processing Record 34 of Set 12 | gravdal
# Processing Record 35 of Set 12 | mandalgovi
# Processing Record 36 of Set 12 | sinnamary
# Processing Record 37 of Set 12 | gambela
# Processing Record 38 of Set 12 | polignano a mare
# Processing Record 39 of Set 12 | melchor de mencos
# Processing Record 40 of Set 12 | nemuro
# Processing Record 41 of Set 12 | paso de los toros
# Processing Record 42 of Set 12 | kanashevo
# Processing Record 43 of Set 12 | hualmay
# Processing Record 44 of Set 12 | catamarca
# Processing Record 45 of Set 12 | yeniseysk
# Processing Record 46 of Set 12 | amazar
# Processing Record 47 of Set 12 | tazovskiy
# Processing Record 48 of Set 12 | charters towers
# Processing Record 49 of Set 12 | calvinia
# Processing Record 50 of Set 12 | vavuniya
# Processing Record 1 of Set 13 | kieta
# Processing Record 2 of Set 13 | hervey bay
# Processing Record 3 of Set 13 | aykhal
# Processing Record 4 of Set 13 | namatanai
# Processing Record 5 of Set 13 | biak
# Processing Record 6 of Set 13 | timra
# Processing Record 7 of Set 13 | kailua
# Processing Record 8 of Set 13 | kaduqli
# Processing Record 9 of Set 13 | caravelas
# Processing Record 10 of Set 13 | saint-georges
# Processing Record 11 of Set 13 | lishui
# Processing Record 12 of Set 13 | zhanakorgan
# Processing Record 13 of Set 13 | save
# Processing Record 14 of Set 13 | cosoleacaque
# Processing Record 15 of Set 13 | banamba
# Processing Record 16 of Set 13 | quelimane
# Processing Record 17 of Set 13 | mogocha
# Processing Record 18 of Set 13 | kedrovyy
# Processing Record 19 of Set 13 | kaka
# Processing Record 20 of Set 13 | mount gambier
# Processing Record 21 of Set 13 | pakxan
# Processing Record 22 of Set 13 | luz
# Processing Record 23 of Set 13 | neiafu
# Processing Record 24 of Set 13 | batemans bay
# Processing Record 25 of Set 13 | culipapa
# City not found. Skipping...
# Processing Record 26 of Set 13 | buritis
# Processing Record 27 of Set 13 | varhaug
# Processing Record 28 of Set 13 | visby
# Processing Record 29 of Set 13 | sabha
# Processing Record 30 of Set 13 | mengcheng
# Processing Record 31 of Set 13 | sao filipe
# Processing Record 32 of Set 13 | puerto escondido
# Processing Record 33 of Set 13 | hohhot
# Processing Record 34 of Set 13 | araouane
# Processing Record 35 of Set 13 | pemba
# Processing Record 36 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 13 | altay
# Processing Record 38 of Set 13 | soe
# Processing Record 39 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 13 | keizer
# Processing Record 41 of Set 13 | rio gallegos
# Processing Record 42 of Set 13 | henties bay
# Processing Record 43 of Set 13 | correntina
# Processing Record 44 of Set 13 | muisne
# Processing Record 45 of Set 13 | yanam
# Processing Record 46 of Set 13 | richards bay
# Processing Record 47 of Set 13 | portland
# Processing Record 48 of Set 13 | grand-santi
# Processing Record 49 of Set 13 | kyabe
# Processing Record 50 of Set 13 | vigrestad
# Processing Record 1 of Set 14 | eidfjord
# Processing Record 2 of Set 14 | bastia
# Processing Record 3 of Set 14 | cherskiy
# Processing Record 4 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 14 | nanjing
# Processing Record 6 of Set 14 | makarov
# Processing Record 7 of Set 14 | lasa
# Processing Record 8 of Set 14 | mecca
# Processing Record 9 of Set 14 | northam
# Processing Record 10 of Set 14 | juba
# Processing Record 11 of Set 14 | dakar
# Processing Record 12 of Set 14 | bubaque
# Processing Record 13 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 14 of Set 14 | miri
# Processing Record 15 of Set 14 | makokou
# Processing Record 16 of Set 14 | nyurba
# Processing Record 17 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 14 | porto belo
# Processing Record 19 of Set 14 | ixtapa
# Processing Record 20 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 14 | jacareacanga
# Processing Record 22 of Set 14 | novyy redant
# City not found. Skipping...
# Processing Record 23 of Set 14 | singkang
# Processing Record 24 of Set 14 | naryan-mar
# Processing Record 25 of Set 14 | husavik
# Processing Record 26 of Set 14 | mormugao
# Processing Record 27 of Set 14 | mahabad
# Processing Record 28 of Set 14 | hambantota
# Processing Record 29 of Set 14 | parral
# Processing Record 30 of Set 14 | conceicao do araguaia
# Processing Record 31 of Set 14 | dehloran
# Processing Record 32 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 14 | jijiga
# Processing Record 34 of Set 14 | harbin
# Processing Record 35 of Set 14 | soyo
# Processing Record 36 of Set 14 | nioro
# Processing Record 37 of Set 14 | mount isa
# Processing Record 38 of Set 14 | pesqueria
# Processing Record 39 of Set 14 | verbivka
# Processing Record 40 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 14 | san rafael del sur
# Processing Record 42 of Set 14 | sabzevar
# Processing Record 43 of Set 14 | ponta grossa
# Processing Record 44 of Set 14 | chernyshevskiy
# Processing Record 45 of Set 14 | onega
# Processing Record 46 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 14 | palani
# Processing Record 48 of Set 14 | kununurra
# Processing Record 49 of Set 14 | kaz
# Processing Record 50 of Set 14 | ucluelet
# Processing Record 1 of Set 15 | kandrian
# Processing Record 2 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 3 of Set 15 | sambava
# Processing Record 4 of Set 15 | maua
# Processing Record 5 of Set 15 | lima
# Processing Record 6 of Set 15 | ust-ilimsk
# Processing Record 7 of Set 15 | bezenchuk
# Processing Record 8 of Set 15 | sept-iles
# Processing Record 9 of Set 15 | timmins
# Processing Record 10 of Set 15 | wajima
# Processing Record 11 of Set 15 | batagay-alyta
# Processing Record 12 of Set 15 | konstantinovka
# Processing Record 13 of Set 15 | acucena
# Processing Record 14 of Set 15 | turtkul
# City not found. Skipping...
# Processing Record 15 of Set 15 | koslan
# Processing Record 16 of Set 15 | la ronge
# Processing Record 17 of Set 15 | huarmey
# Processing Record 18 of Set 15 | burhar
# Processing Record 19 of Set 15 | chipinge
# Processing Record 20 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 21 of Set 15 | leningradskiy
# Processing Record 22 of Set 15 | marsh harbour
# Processing Record 23 of Set 15 | udachnyy
# Processing Record 24 of Set 15 | antofagasta
# Processing Record 25 of Set 15 | kokstad
# Processing Record 26 of Set 15 | champerico
# Processing Record 27 of Set 15 | gamba
# Processing Record 28 of Set 15 | clinton
# Processing Record 29 of Set 15 | pisco
# Processing Record 30 of Set 15 | ulladulla
# Processing Record 31 of Set 15 | yabrud
# Processing Record 32 of Set 15 | rapid valley
# Processing Record 33 of Set 15 | xinxiang
# Processing Record 34 of Set 15 | porto walter
# Processing Record 35 of Set 15 | san carlos
# Processing Record 36 of Set 15 | jagtial
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mahebourg      MU -20.41   57.70     69.80        94          75
# 1           Agudos      BR -22.47  -48.99     80.60        42           3
# 2  Arraial Do Cabo      BR -22.97  -42.03     75.20        60           0
# 3           Barrow      US  71.29 -156.79     33.80        86          90
# 4         Zhigansk      RU  66.77  123.37     53.44        67           0
# 5            Tiksi      RU  71.69  128.87     43.32        81           0
# 6           Pionki      PL  51.48   21.45     66.00        97           0
# 7            Opuwo      NA -18.06   13.84     62.20        31           0
# 8           Bosaso      SO  11.28   49.18     89.20        52          31
# 9   Port Shepstone      ZA -30.74   30.45     62.96        48           0
#
#    Wind Speed Curent Description
# 0       14.99        shower rain
# 1        3.36          clear sky
# 2        9.17          clear sky
# 3        4.70    overcast clouds
# 4       12.26          clear sky
# 5        3.22          clear sky
# 6        4.74          clear sky
# 7        8.30          clear sky
# 8       10.94   scattered clouds
# 9        5.30          clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
