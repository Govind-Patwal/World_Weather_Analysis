# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1       
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | sao filipe
# Processing Record 3 of Set 1 | souillac
# Processing Record 4 of Set 1 | dholka
# Processing Record 5 of Set 1 | saint-augustin
# Processing Record 6 of Set 1 | sechura
# Processing Record 7 of Set 1 | stornoway
# Processing Record 8 of Set 1 | palm coast
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | ayia galini
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | gali
# Processing Record 19 of Set 1 | awbari
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | chapais
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | flinders
# Processing Record 35 of Set 1 | pangnirtung
# Processing Record 36 of Set 1 | natal
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 1 | srednekolymsk
# Processing Record 41 of Set 1 | cap malheureux
# Processing Record 42 of Set 1 | porto recanati
# Processing Record 43 of Set 1 | san policarpo
# Processing Record 44 of Set 1 | salym
# Processing Record 45 of Set 1 | vestmannaeyjar
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | vardo
# Processing Record 48 of Set 1 | saldanha
# Processing Record 49 of Set 1 | adrar
# Processing Record 50 of Set 1 | jalu
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | vilyuysk
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | hami
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | esperance
# Processing Record 7 of Set 2 | pervomayskoye
# Processing Record 8 of Set 2 | kiunga
# Processing Record 9 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 2 | ghanzi
# Processing Record 11 of Set 2 | ilo
# Processing Record 12 of Set 2 | santa cruz de la palma
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | codrington
# Processing Record 15 of Set 2 | pangkalanbuun
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | paita
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | leningradskiy
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | gat
# Processing Record 23 of Set 2 | touros
# Processing Record 24 of Set 2 | marica
# Processing Record 25 of Set 2 | nouadhibou
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | geraldton
# Processing Record 28 of Set 2 | peremyshl
# Processing Record 29 of Set 2 | narsaq
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | salinopolis
# Processing Record 32 of Set 2 | bilibino
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | torbay
# Processing Record 37 of Set 2 | port hedland
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 40 of Set 2 | sitka
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | praia da vitoria
# Processing Record 44 of Set 2 | port macquarie
# Processing Record 45 of Set 2 | port hardy
# Processing Record 46 of Set 2 | olinda
# Processing Record 47 of Set 2 | carman
# Processing Record 48 of Set 2 | osmena
# Processing Record 49 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 2 | samarai
# Processing Record 1 of Set 3 | provideniya
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | tocopilla
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | marrakesh
# Processing Record 8 of Set 3 | diamantina
# Processing Record 9 of Set 3 | coari
# Processing Record 10 of Set 3 | jiangyou
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 3 | dukat
# Processing Record 14 of Set 3 | praia
# Processing Record 15 of Set 3 | vostok
# Processing Record 16 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 3 | surab
# Processing Record 18 of Set 3 | vaini
# Processing Record 19 of Set 3 | raga
# Processing Record 20 of Set 3 | khatanga
# Processing Record 21 of Set 3 | smithers
# Processing Record 22 of Set 3 | saint-georges
# Processing Record 23 of Set 3 | faanui
# Processing Record 24 of Set 3 | green river
# Processing Record 25 of Set 3 | klaksvik
# Processing Record 26 of Set 3 | arman
# Processing Record 27 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 3 | california
# Processing Record 29 of Set 3 | gudalur
# Processing Record 30 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 3 | cumra
# Processing Record 32 of Set 3 | kamyaran
# Processing Record 33 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | kapit
# Processing Record 37 of Set 3 | baryatino
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | mariel
# Processing Record 41 of Set 3 | avarua
# Processing Record 42 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 3 | chute-aux-outardes
# Processing Record 45 of Set 3 | cherskiy
# Processing Record 46 of Set 3 | roma
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | norman wells
# Processing Record 49 of Set 3 | constitucion
# Processing Record 50 of Set 3 | belaya gora
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | dunedin
# Processing Record 4 of Set 4 | batagay
# Processing Record 5 of Set 4 | vuktyl
# Processing Record 6 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 4 | bingol
# Processing Record 8 of Set 4 | lahaina
# Processing Record 9 of Set 4 | kruszwica
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | hun
# Processing Record 13 of Set 4 | haines junction
# Processing Record 14 of Set 4 | vanderbijlpark
# Processing Record 15 of Set 4 | ribeira grande
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | mount isa
# Processing Record 19 of Set 4 | tsabong
# Processing Record 20 of Set 4 | camacha
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | ancud
# Processing Record 23 of Set 4 | san juan
# Processing Record 24 of Set 4 | richards bay
# Processing Record 25 of Set 4 | abilene
# Processing Record 26 of Set 4 | athni
# Processing Record 27 of Set 4 | acarau
# Processing Record 28 of Set 4 | san michele al tagliamento
# Processing Record 29 of Set 4 | vanimo
# Processing Record 30 of Set 4 | quelimane
# Processing Record 31 of Set 4 | husavik
# Processing Record 32 of Set 4 | paracuru
# Processing Record 33 of Set 4 | auki
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | raudeberg
# Processing Record 36 of Set 4 | eureka
# Processing Record 37 of Set 4 | riberalta
# Processing Record 38 of Set 4 | beringovskiy
# Processing Record 39 of Set 4 | evensk
# Processing Record 40 of Set 4 | pontes e lacerda
# Processing Record 41 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 4 | rantauprapat
# Processing Record 43 of Set 4 | calama
# Processing Record 44 of Set 4 | bambous virieux
# Processing Record 45 of Set 4 | mitsamiouli
# Processing Record 46 of Set 4 | carnarvon
# Processing Record 47 of Set 4 | lakshettipet
# Processing Record 48 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 4 | sao gabriel da cachoeira
# Processing Record 50 of Set 4 | koundara
# Processing Record 1 of Set 5 | mchinji
# Processing Record 2 of Set 5 | vila franca do campo
# Processing Record 3 of Set 5 | viedma
# Processing Record 4 of Set 5 | shurugwi
# Processing Record 5 of Set 5 | linhares
# Processing Record 6 of Set 5 | east london
# Processing Record 7 of Set 5 | porto empedocle
# Processing Record 8 of Set 5 | rovaniemi
# Processing Record 9 of Set 5 | tucuma
# Processing Record 10 of Set 5 | yaan
# Processing Record 11 of Set 5 | broome
# Processing Record 12 of Set 5 | talca
# Processing Record 13 of Set 5 | zhigansk
# Processing Record 14 of Set 5 | zelenoborsk
# Processing Record 15 of Set 5 | ust-tsilma
# Processing Record 16 of Set 5 | yecla
# Processing Record 17 of Set 5 | hamilton
# Processing Record 18 of Set 5 | mahebourg
# Processing Record 19 of Set 5 | alappuzha
# Processing Record 20 of Set 5 | killybegs
# Processing Record 21 of Set 5 | ekhabi
# Processing Record 22 of Set 5 | quetzaltepec
# City not found. Skipping...
# Processing Record 23 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 24 of Set 5 | nikolayevka
# Processing Record 25 of Set 5 | laguna
# Processing Record 26 of Set 5 | rocha
# Processing Record 27 of Set 5 | ca mau
# Processing Record 28 of Set 5 | mersin
# Processing Record 29 of Set 5 | aklavik
# Processing Record 30 of Set 5 | vao
# Processing Record 31 of Set 5 | yueyang
# Processing Record 32 of Set 5 | tuxtla
# Processing Record 33 of Set 5 | berlevag
# Processing Record 34 of Set 5 | port elizabeth
# Processing Record 35 of Set 5 | acapulco
# Processing Record 36 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 5 | zakamensk
# Processing Record 39 of Set 5 | shitanjing
# Processing Record 40 of Set 5 | stepnogorsk
# Processing Record 41 of Set 5 | ayoquezco
# City not found. Skipping...
# Processing Record 42 of Set 5 | kruisfontein
# Processing Record 43 of Set 5 | quatre cocos
# Processing Record 44 of Set 5 | russell
# Processing Record 45 of Set 5 | totskoye
# Processing Record 46 of Set 5 | chivilcoy
# Processing Record 47 of Set 5 | artyom
# Processing Record 48 of Set 5 | zapolyarnyy
# Processing Record 49 of Set 5 | hurghada
# Processing Record 50 of Set 5 | umtata
# Processing Record 1 of Set 6 | suzhou
# Processing Record 2 of Set 6 | vila velha
# Processing Record 3 of Set 6 | masvingo
# Processing Record 4 of Set 6 | rennes
# Processing Record 5 of Set 6 | bumba
# Processing Record 6 of Set 6 | bundaberg
# Processing Record 7 of Set 6 | qazvin
# Processing Record 8 of Set 6 | vegreville
# Processing Record 9 of Set 6 | casper
# Processing Record 10 of Set 6 | teya
# Processing Record 11 of Set 6 | glendive
# Processing Record 12 of Set 6 | lata
# Processing Record 13 of Set 6 | zyryanka
# Processing Record 14 of Set 6 | sibolga
# Processing Record 15 of Set 6 | jijiga
# Processing Record 16 of Set 6 | stromness
# Processing Record 17 of Set 6 | taltal
# Processing Record 18 of Set 6 | nome
# Processing Record 19 of Set 6 | saint george
# Processing Record 20 of Set 6 | nyurba
# Processing Record 21 of Set 6 | othaya
# Processing Record 22 of Set 6 | belyy yar
# Processing Record 23 of Set 6 | abeokuta
# Processing Record 24 of Set 6 | asyut
# Processing Record 25 of Set 6 | omboue
# Processing Record 26 of Set 6 | rio gallegos
# Processing Record 27 of Set 6 | kinablangan
# Processing Record 28 of Set 6 | listvyagi
# Processing Record 29 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 6 | verkhoyansk
# Processing Record 31 of Set 6 | neenah
# Processing Record 32 of Set 6 | kalawit
# Processing Record 33 of Set 6 | san jose
# Processing Record 34 of Set 6 | hasaki
# Processing Record 35 of Set 6 | aqtobe
# Processing Record 36 of Set 6 | talnakh
# Processing Record 37 of Set 6 | brooklyn
# Processing Record 38 of Set 6 | harrison
# Processing Record 39 of Set 6 | mvuma
# Processing Record 40 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 6 | qasigiannguit
# Processing Record 42 of Set 6 | coquimbo
# Processing Record 43 of Set 6 | skjervoy
# Processing Record 44 of Set 6 | hervey bay
# Processing Record 45 of Set 6 | la paz
# Processing Record 46 of Set 6 | maldonado
# Processing Record 47 of Set 6 | valparaiso
# Processing Record 48 of Set 6 | nabire
# Processing Record 49 of Set 6 | peniche
# Processing Record 50 of Set 6 | flin flon
# Processing Record 1 of Set 7 | zalantun
# Processing Record 2 of Set 7 | cayenne
# Processing Record 3 of Set 7 | yanam
# Processing Record 4 of Set 7 | abalak
# Processing Record 5 of Set 7 | buenos aires
# Processing Record 6 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 7 of Set 7 | nanortalik
# Processing Record 8 of Set 7 | slave lake
# Processing Record 9 of Set 7 | lagoa
# Processing Record 10 of Set 7 | chicama
# Processing Record 11 of Set 7 | kununurra
# Processing Record 12 of Set 7 | sapa
# Processing Record 13 of Set 7 | kavieng
# Processing Record 14 of Set 7 | krasnyye barrikady
# Processing Record 15 of Set 7 | teguise
# Processing Record 16 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 7 | byron bay
# Processing Record 18 of Set 7 | guerrero negro
# Processing Record 19 of Set 7 | coihaique
# Processing Record 20 of Set 7 | elizabeth city
# Processing Record 21 of Set 7 | qaqortoq
# Processing Record 22 of Set 7 | gander
# Processing Record 23 of Set 7 | tautira
# Processing Record 24 of Set 7 | atar
# Processing Record 25 of Set 7 | port-cartier
# Processing Record 26 of Set 7 | saint pete beach
# Processing Record 27 of Set 7 | meulaboh
# Processing Record 28 of Set 7 | yangjiang
# Processing Record 29 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 30 of Set 7 | pisco
# Processing Record 31 of Set 7 | nantucket
# Processing Record 32 of Set 7 | hobyo
# Processing Record 33 of Set 7 | manta
# Processing Record 34 of Set 7 | mbanza-ngungu
# Processing Record 35 of Set 7 | lyuban
# Processing Record 36 of Set 7 | maceio
# Processing Record 37 of Set 7 | ubinskoye
# Processing Record 38 of Set 7 | bindura
# Processing Record 39 of Set 7 | cururupu
# Processing Record 40 of Set 7 | carpinteria
# Processing Record 41 of Set 7 | mumford
# Processing Record 42 of Set 7 | san carlos
# Processing Record 43 of Set 7 | los llanos de aridane
# Processing Record 44 of Set 7 | esso
# Processing Record 45 of Set 7 | xichang
# Processing Record 46 of Set 7 | gold coast
# Processing Record 47 of Set 7 | dezful
# Processing Record 48 of Set 7 | kirillov
# Processing Record 49 of Set 7 | santa rosa
# Processing Record 50 of Set 7 | korla
# Processing Record 1 of Set 8 | soyo
# Processing Record 2 of Set 8 | winsum
# Processing Record 3 of Set 8 | ostrovnoy
# Processing Record 4 of Set 8 | atambua
# Processing Record 5 of Set 8 | yamada
# Processing Record 6 of Set 8 | grindavik
# Processing Record 7 of Set 8 | svetlogorsk
# Processing Record 8 of Set 8 | sindor
# Processing Record 9 of Set 8 | shulan
# Processing Record 10 of Set 8 | yago
# Processing Record 11 of Set 8 | nam som
# Processing Record 12 of Set 8 | portland
# Processing Record 13 of Set 8 | port moresby
# Processing Record 14 of Set 8 | avera
# Processing Record 15 of Set 8 | tiznit
# Processing Record 16 of Set 8 | kahului
# Processing Record 17 of Set 8 | karpathos
# Processing Record 18 of Set 8 | turinsk
# Processing Record 19 of Set 8 | iqaluit
# Processing Record 20 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 8 | mayo
# Processing Record 22 of Set 8 | fare
# Processing Record 23 of Set 8 | batemans bay
# Processing Record 24 of Set 8 | labuhan
# Processing Record 25 of Set 8 | trat
# Processing Record 26 of Set 8 | wagar
# Processing Record 27 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 28 of Set 8 | mill valley
# Processing Record 29 of Set 8 | ilabaya
# Processing Record 30 of Set 8 | langenhagen
# Processing Record 31 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 8 | college
# Processing Record 33 of Set 8 | landshut
# Processing Record 34 of Set 8 | mehamn
# Processing Record 35 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 36 of Set 8 | teseney
# Processing Record 37 of Set 8 | talcahuano
# Processing Record 38 of Set 8 | pangody
# Processing Record 39 of Set 8 | ulladulla
# Processing Record 40 of Set 8 | nizamabad
# Processing Record 41 of Set 8 | bonavista
# Processing Record 42 of Set 8 | muravlenko
# Processing Record 43 of Set 8 | inuvik
# Processing Record 44 of Set 8 | balung
# Processing Record 45 of Set 8 | yar
# Processing Record 46 of Set 8 | nan
# Processing Record 47 of Set 8 | serenje
# Processing Record 48 of Set 8 | mirnyy
# Processing Record 49 of Set 8 | pochutla
# Processing Record 50 of Set 8 | benguela
# Processing Record 1 of Set 9 | taoudenni
# Processing Record 2 of Set 9 | deputatskiy
# Processing Record 3 of Set 9 | aksu
# Processing Record 4 of Set 9 | manokwari
# Processing Record 5 of Set 9 | fortuna
# Processing Record 6 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 9 | georgetown
# Processing Record 8 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 9 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 10 of Set 9 | kenora
# Processing Record 11 of Set 9 | agadir
# Processing Record 12 of Set 9 | road town
# Processing Record 13 of Set 9 | huarmey
# Processing Record 14 of Set 9 | mackay
# Processing Record 15 of Set 9 | yuncheng
# Processing Record 16 of Set 9 | ipixuna
# Processing Record 17 of Set 9 | beyneu
# Processing Record 18 of Set 9 | marsh harbour
# Processing Record 19 of Set 9 | shimoda
# Processing Record 20 of Set 9 | marawi
# Processing Record 21 of Set 9 | kingussie
# Processing Record 22 of Set 9 | sarana
# Processing Record 23 of Set 9 | nelson bay
# Processing Record 24 of Set 9 | rafaela
# Processing Record 25 of Set 9 | kombissiri
# Processing Record 26 of Set 9 | bud
# Processing Record 27 of Set 9 | oktyabrskoye
# Processing Record 28 of Set 9 | serik
# Processing Record 29 of Set 9 | bathsheba
# Processing Record 30 of Set 9 | lasa
# Processing Record 31 of Set 9 | tilichiki
# Processing Record 32 of Set 9 | chanute
# Processing Record 33 of Set 9 | isabela
# Processing Record 34 of Set 9 | noratus
# Processing Record 35 of Set 9 | santa cruz de tenerife
# Processing Record 36 of Set 9 | kifri
# Processing Record 37 of Set 9 | kailua
# Processing Record 38 of Set 9 | khandyga
# Processing Record 39 of Set 9 | barreirinha
# Processing Record 40 of Set 9 | poum
# Processing Record 41 of Set 9 | monte azul
# Processing Record 42 of Set 9 | nemuro
# Processing Record 43 of Set 9 | twin falls
# Processing Record 44 of Set 9 | qurayyat
# Processing Record 45 of Set 9 | panjakent
# Processing Record 46 of Set 9 | kachiry
# Processing Record 47 of Set 9 | ballina
# Processing Record 48 of Set 9 | kiama
# Processing Record 49 of Set 9 | thinadhoo
# Processing Record 50 of Set 9 | vilcun
# Processing Record 1 of Set 10 | novoagansk
# Processing Record 2 of Set 10 | malpe
# Processing Record 3 of Set 10 | fayaoue
# Processing Record 4 of Set 10 | bubaque
# Processing Record 5 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 10 | benghazi
# Processing Record 7 of Set 10 | ishinomaki
# Processing Record 8 of Set 10 | oussouye
# Processing Record 9 of Set 10 | tromso
# Processing Record 10 of Set 10 | honiara
# Processing Record 11 of Set 10 | las vegas
# Processing Record 12 of Set 10 | santa margarita
# Processing Record 13 of Set 10 | rantepao
# Processing Record 14 of Set 10 | rio grande
# Processing Record 15 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 10 | xiaoweizhai
# Processing Record 17 of Set 10 | lat yao
# Processing Record 18 of Set 10 | macusani
# Processing Record 19 of Set 10 | xadani
# City not found. Skipping...
# Processing Record 20 of Set 10 | swift current
# Processing Record 21 of Set 10 | saint-prosper
# Processing Record 22 of Set 10 | onega
# Processing Record 23 of Set 10 | sobolevo
# Processing Record 24 of Set 10 | hualmay
# Processing Record 25 of Set 10 | baruun-urt
# Processing Record 26 of Set 10 | pouebo
# Processing Record 27 of Set 10 | lyngseidet
# Processing Record 28 of Set 10 | chara
# Processing Record 29 of Set 10 | tuatapere
# Processing Record 30 of Set 10 | port lincoln
# Processing Record 31 of Set 10 | borovichi
# Processing Record 32 of Set 10 | nishihara
# Processing Record 33 of Set 10 | namibe
# Processing Record 34 of Set 10 | mataram
# Processing Record 35 of Set 10 | sorong
# Processing Record 36 of Set 10 | teahupoo
# Processing Record 37 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 10 | tura
# Processing Record 39 of Set 10 | narok
# Processing Record 40 of Set 10 | lavrentiya
# Processing Record 41 of Set 10 | aragats
# Processing Record 42 of Set 10 | amapa
# Processing Record 43 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 10 | alofi
# Processing Record 46 of Set 10 | cockburn town
# Processing Record 47 of Set 10 | mehendiganj
# Processing Record 48 of Set 10 | high level
# Processing Record 49 of Set 10 | sakaiminato
# Processing Record 50 of Set 10 | hirara
# Processing Record 1 of Set 11 | kurilsk
# Processing Record 2 of Set 11 | fengkou
# Processing Record 3 of Set 11 | canton
# Processing Record 4 of Set 11 | nanyuki
# Processing Record 5 of Set 11 | henties bay
# Processing Record 6 of Set 11 | hofn
# Processing Record 7 of Set 11 | xuddur
# Processing Record 8 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 11 | kamaishi
# Processing Record 11 of Set 11 | havre-saint-pierre
# Processing Record 12 of Set 11 | fairbanks
# Processing Record 13 of Set 11 | shingu
# Processing Record 14 of Set 11 | verkhnevilyuysk
# Processing Record 15 of Set 11 | methoni
# Processing Record 16 of Set 11 | kavaratti
# Processing Record 17 of Set 11 | piryion
# City not found. Skipping...
# Processing Record 18 of Set 11 | maragogi
# Processing Record 19 of Set 11 | rypefjord
# Processing Record 20 of Set 11 | lubango
# Processing Record 21 of Set 11 | olafsvik
# Processing Record 22 of Set 11 | san patricio
# Processing Record 23 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 24 of Set 11 | toungoo
# City not found. Skipping...
# Processing Record 25 of Set 11 | lima
# Processing Record 26 of Set 11 | chenghai
# Processing Record 27 of Set 11 | matayumtayum
# Processing Record 28 of Set 11 | ak-dovurak
# Processing Record 29 of Set 11 | ginir
# Processing Record 30 of Set 11 | waipawa
# Processing Record 31 of Set 11 | elko
# Processing Record 32 of Set 11 | siyabuswa
# Processing Record 33 of Set 11 | naze
# Processing Record 34 of Set 11 | makakilo city
# Processing Record 35 of Set 11 | maryville
# Processing Record 36 of Set 11 | hovd
# Processing Record 37 of Set 11 | ponta delgada
# Processing Record 38 of Set 11 | nevelsk
# Processing Record 39 of Set 11 | ingham
# Processing Record 40 of Set 11 | belmonte
# Processing Record 41 of Set 11 | grand-santi
# Processing Record 42 of Set 11 | lorengau
# Processing Record 43 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 44 of Set 11 | mogok
# Processing Record 45 of Set 11 | new milford
# Processing Record 46 of Set 11 | tabuk
# Processing Record 47 of Set 11 | antofagasta
# Processing Record 48 of Set 11 | caxito
# Processing Record 49 of Set 11 | komsomolskiy
# Processing Record 50 of Set 11 | shakiso
# Processing Record 1 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 2 of Set 12 | conakry
# Processing Record 3 of Set 12 | manama
# Processing Record 4 of Set 12 | fort nelson
# Processing Record 5 of Set 12 | lazaro cardenas
# Processing Record 6 of Set 12 | te anau
# Processing Record 7 of Set 12 | rabo de peixe
# Processing Record 8 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 12 | kumano
# Processing Record 10 of Set 12 | santa cruz
# Processing Record 11 of Set 12 | tulun
# Processing Record 12 of Set 12 | kutum
# Processing Record 13 of Set 12 | wichian buri
# Processing Record 14 of Set 12 | lac du bonnet
# Processing Record 15 of Set 12 | port-gentil
# Processing Record 16 of Set 12 | nihommatsu
# Processing Record 17 of Set 12 | mabai
# Processing Record 18 of Set 12 | manakara
# Processing Record 19 of Set 12 | ivangorod
# Processing Record 20 of Set 12 | clonakilty
# Processing Record 21 of Set 12 | imbituba
# Processing Record 22 of Set 12 | ilulissat
# Processing Record 23 of Set 12 | pucallpa
# Processing Record 24 of Set 12 | savannah bight
# Processing Record 25 of Set 12 | plettenberg bay
# Processing Record 26 of Set 12 | uvira
# Processing Record 27 of Set 12 | kyrksaeterora
# Processing Record 28 of Set 12 | planeta rica
# Processing Record 29 of Set 12 | naryan-mar
# Processing Record 30 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 12 | sandnessjoen
# Processing Record 32 of Set 12 | saint-pierre
# Processing Record 33 of Set 12 | opuwo
# Processing Record 34 of Set 12 | murgab
# Processing Record 35 of Set 12 | tadine
# Processing Record 36 of Set 12 | ternate
# Processing Record 37 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 12 | batagay-alyta
# Processing Record 39 of Set 12 | broken hill
# Processing Record 40 of Set 12 | cabo san lucas
# Processing Record 41 of Set 12 | okha
# Processing Record 42 of Set 12 | blythe
# Processing Record 43 of Set 12 | krasnoselkup
# Processing Record 44 of Set 12 | shirokiy
# Processing Record 45 of Set 12 | dera din panah
# City not found. Skipping...
# Processing Record 46 of Set 12 | diamantino
# Processing Record 47 of Set 12 | ketchikan
# Processing Record 48 of Set 12 | san javier
# Processing Record 49 of Set 12 | abeche
# Processing Record 50 of Set 12 | beloha
# Processing Record 1 of Set 13 | severo-yeniseyskiy
# Processing Record 2 of Set 13 | yulara
# Processing Record 3 of Set 13 | uklana mandi
# Processing Record 4 of Set 13 | gweta
# Processing Record 5 of Set 13 | liwale
# Processing Record 6 of Set 13 | paraguari
# Processing Record 7 of Set 13 | krasnokholmskiy
# Processing Record 8 of Set 13 | turiacu
# Processing Record 9 of Set 13 | mzimba
# Processing Record 10 of Set 13 | andenes
# Processing Record 11 of Set 13 | quesnel
# Processing Record 12 of Set 13 | turkeve
# Processing Record 13 of Set 13 | lodwar
# Processing Record 14 of Set 13 | kochki
# Processing Record 15 of Set 13 | gazojak
# Processing Record 16 of Set 13 | carballo
# Processing Record 17 of Set 13 | vila do maio
# Processing Record 18 of Set 13 | kavant
# City not found. Skipping...
# Processing Record 19 of Set 13 | selma
# Processing Record 20 of Set 13 | grand baie
# Processing Record 21 of Set 13 | ixtapa
# Processing Record 22 of Set 13 | waingapu
# Processing Record 23 of Set 13 | miandrivazo
# Processing Record 24 of Set 13 | gizo
# Processing Record 25 of Set 13 | mataro
# Processing Record 26 of Set 13 | kasane
# Processing Record 27 of Set 13 | tazovskiy
# Processing Record 28 of Set 13 | bucerias
# Processing Record 29 of Set 13 | manzhouli
# Processing Record 30 of Set 13 | kuandian
# Processing Record 31 of Set 13 | trelew
# Processing Record 32 of Set 13 | paullo
# Processing Record 33 of Set 13 | delmas
# Processing Record 34 of Set 13 | sakakah
# Processing Record 35 of Set 13 | tarcau
# Processing Record 36 of Set 13 | kermanshah
# Processing Record 37 of Set 13 | aitape
# Processing Record 38 of Set 13 | ha tinh
# Processing Record 39 of Set 13 | xinmin
# Processing Record 40 of Set 13 | camargo
# Processing Record 41 of Set 13 | havoysund
# Processing Record 42 of Set 13 | almansa
# Processing Record 43 of Set 13 | minab
# Processing Record 44 of Set 13 | olga
# Processing Record 45 of Set 13 | alice town
# Processing Record 46 of Set 13 | tongren
# Processing Record 47 of Set 13 | saint anthony
# Processing Record 48 of Set 13 | dombarovskiy
# Processing Record 49 of Set 13 | melo
# Processing Record 50 of Set 13 | kuching
# Processing Record 1 of Set 14 | dubbo
# Processing Record 2 of Set 14 | keti bandar
# Processing Record 3 of Set 14 | mana
# Processing Record 4 of Set 14 | roura
# Processing Record 5 of Set 14 | tabou
# Processing Record 6 of Set 14 | luoyang
# Processing Record 7 of Set 14 | noumea
# Processing Record 8 of Set 14 | campbell river
# Processing Record 9 of Set 14 | el alto
# Processing Record 10 of Set 14 | taksimo
# Processing Record 11 of Set 14 | saalfeld
# Processing Record 12 of Set 14 | tulum
# Processing Record 13 of Set 14 | sao joao da barra
# Processing Record 14 of Set 14 | plaeng yao
# Processing Record 15 of Set 14 | asau
# Processing Record 16 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 14 | spirit river
# Processing Record 18 of Set 14 | secunda
# Processing Record 19 of Set 14 | umm kaddadah
# Processing Record 20 of Set 14 | dwarka
# Processing Record 21 of Set 14 | mao
# Processing Record 22 of Set 14 | robertsport
# Processing Record 23 of Set 14 | birao
# Processing Record 24 of Set 14 | san felipe
# Processing Record 25 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 14 | spring valley
# Processing Record 27 of Set 14 | cabedelo
# Processing Record 28 of Set 14 | port blair
# Processing Record 29 of Set 14 | lensk
# Processing Record 30 of Set 14 | haapu
# City not found. Skipping...
# Processing Record 31 of Set 14 | ponta grossa
# Processing Record 32 of Set 14 | bangangte
# Processing Record 33 of Set 14 | solnechnyy
# Processing Record 34 of Set 14 | yerbogachen
# Processing Record 35 of Set 14 | tarumovka
# Processing Record 36 of Set 14 | san borja
# Processing Record 37 of Set 14 | glenwood springs
# Processing Record 38 of Set 14 | ligayan
# Processing Record 39 of Set 14 | andrews
# Processing Record 40 of Set 14 | cairns
# Processing Record 41 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 42 of Set 14 | formosa
# Processing Record 43 of Set 14 | seoul
# Processing Record 44 of Set 14 | katherine
# Processing Record 45 of Set 14 | tarko-sale
# Processing Record 46 of Set 14 | maralal
# Processing Record 47 of Set 14 | davila
# Processing Record 48 of Set 14 | jiwani
# Processing Record 49 of Set 14 | antalaha
# Processing Record 50 of Set 14 | wasilla
# Processing Record 1 of Set 15 | lagunas
# Processing Record 2 of Set 15 | linda
# Processing Record 3 of Set 15 | salalah
# Processing Record 4 of Set 15 | kigoma
# Processing Record 5 of Set 15 | rumphi
# Processing Record 6 of Set 15 | ozernovskiy
# Processing Record 7 of Set 15 | shache
# Processing Record 8 of Set 15 | puerto morazan
# Processing Record 9 of Set 15 | malibu
# Processing Record 10 of Set 15 | amagi
# Processing Record 11 of Set 15 | merauke
# Processing Record 12 of Set 15 | bossembele
# City not found. Skipping...
# Processing Record 13 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 14 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 15 | isoka
# Processing Record 16 of Set 15 | wenling
# Processing Record 17 of Set 15 | alice springs
# Processing Record 18 of Set 15 | rjukan
# Processing Record 19 of Set 15 | karratha
# Processing Record 20 of Set 15 | coahuayana
# Processing Record 21 of Set 15 | koubia
# Processing Record 22 of Set 15 | novikovo
# Processing Record 23 of Set 15 | saint-junien
# Processing Record 24 of Set 15 | jaciara
# Processing Record 25 of Set 15 | tirthahalli
# Processing Record 26 of Set 15 | tarrafal
# Processing Record 27 of Set 15 | kasongo-lunda
# Processing Record 28 of Set 15 | arkhangelskaya
# Processing Record 29 of Set 15 | morristown
# Processing Record 30 of Set 15 | newport
# Processing Record 31 of Set 15 | salvador
# Processing Record 32 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 15 | piura
# Processing Record 34 of Set 15 | vero beach
# Processing Record 35 of Set 15 | helong
# Processing Record 36 of Set 15 | san-pedro
# Processing Record 37 of Set 15 | dapaong
# Processing Record 38 of Set 15 | lompoc
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ponta Do Sol      PT  32.67  -17.10     71.01        40           1
# 1      Sao Filipe      CV  14.90  -24.50     77.23        83          11
# 2        Souillac      MU -20.52   57.52     71.60        78          75
# 3          Dholka      IN  22.72   72.47     82.40        83          40
# 4  Saint-Augustin      CA  51.23  -58.65     54.70        94         100
# 5         Sechura      PE  -5.56  -80.82     66.47        72           4
# 6       Stornoway      GB  58.21   -6.39     54.00        91          90
# 7      Palm Coast      US  29.59  -81.21     87.80        55           1
# 8           Airai      TL  -8.93  125.41     63.30        50           0
# 9          Castro      BR -24.79  -50.01     53.11        85           0
#
#    Wind Speed Current Description
# 0        3.56           clear sky
# 1        5.57          few clouds
# 2       14.99         shower rain
# 3        6.93                haze
# 4        2.89     overcast clouds
# 5       14.72           clear sky
# 6        7.56          light rain
# 7        8.05           clear sky
# 8        4.00           clear sky
# 9        3.24           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
