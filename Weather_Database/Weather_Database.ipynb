# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1       
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Curent Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | sokoni
# Processing Record 5 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | kumla
# Processing Record 11 of Set 1 | rawson
# Processing Record 12 of Set 1 | adrar
# Processing Record 13 of Set 1 | arman
# Processing Record 14 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | coquimbo
# Processing Record 19 of Set 1 | alyangula
# Processing Record 20 of Set 1 | biak
# Processing Record 21 of Set 1 | sechura
# Processing Record 22 of Set 1 | cabo san lucas
# Processing Record 23 of Set 1 | srednekolymsk
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | katherine
# Processing Record 26 of Set 1 | tshikapa
# Processing Record 27 of Set 1 | bambous virieux
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | salalah
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | eenhana
# Processing Record 39 of Set 1 | bilma
# Processing Record 40 of Set 1 | jember
# Processing Record 41 of Set 1 | snasa
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 1 | ponte nova
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | peniche
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | hasaki
# Processing Record 49 of Set 1 | herne bay
# Processing Record 50 of Set 1 | camaqua
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | kumluca
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 2 | lakes entrance
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | the valley
# Processing Record 9 of Set 2 | maniitsoq
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | colares
# Processing Record 13 of Set 2 | lugovoy
# Processing Record 14 of Set 2 | ahipara
# Processing Record 15 of Set 2 | zemio
# Processing Record 16 of Set 2 | olinda
# Processing Record 17 of Set 2 | calvinia
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | sosua
# Processing Record 21 of Set 2 | esna
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | leningradskiy
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | khandyga
# Processing Record 26 of Set 2 | belmonte
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | jalu
# Processing Record 29 of Set 2 | quatre cocos
# Processing Record 30 of Set 2 | alice springs
# Processing Record 31 of Set 2 | provideniya
# Processing Record 32 of Set 2 | takoradi
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | lukovetskiy
# Processing Record 36 of Set 2 | esperance
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | sorong
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | freeport
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | romny
# Processing Record 44 of Set 2 | tuatapere
# Processing Record 45 of Set 2 | souillac
# Processing Record 46 of Set 2 | kirakira
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | guerrero negro
# Processing Record 50 of Set 2 | kavieng
# Processing Record 1 of Set 3 | tabuk
# Processing Record 2 of Set 3 | am timan
# Processing Record 3 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | mao
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | brisbane
# Processing Record 10 of Set 3 | san-pedro
# Processing Record 11 of Set 3 | lagoa
# Processing Record 12 of Set 3 | solnechnyy
# Processing Record 13 of Set 3 | san quintin
# Processing Record 14 of Set 3 | qaanaaq
# Processing Record 15 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 3 | winchester
# Processing Record 17 of Set 3 | shenzhen
# Processing Record 18 of Set 3 | mezen
# Processing Record 19 of Set 3 | huarmey
# Processing Record 20 of Set 3 | turukhansk
# Processing Record 21 of Set 3 | cape town
# Processing Record 22 of Set 3 | aden
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | mirnyy
# Processing Record 25 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 3 | nanortalik
# Processing Record 27 of Set 3 | fergus falls
# Processing Record 28 of Set 3 | okhotsk
# Processing Record 29 of Set 3 | severo-kurilsk
# Processing Record 30 of Set 3 | bardsir
# Processing Record 31 of Set 3 | kamaishi
# Processing Record 32 of Set 3 | norman wells
# Processing Record 33 of Set 3 | cidreira
# Processing Record 34 of Set 3 | samarai
# Processing Record 35 of Set 3 | araouane
# Processing Record 36 of Set 3 | pandan
# Processing Record 37 of Set 3 | urubicha
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | katsuura
# Processing Record 41 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 3 | reitz
# Processing Record 43 of Set 3 | poum
# Processing Record 44 of Set 3 | naze
# Processing Record 45 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 3 | majene
# Processing Record 47 of Set 3 | port lavaca
# Processing Record 48 of Set 3 | tezu
# Processing Record 49 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 4 | nhulunbuy
# Processing Record 2 of Set 4 | klamath falls
# Processing Record 3 of Set 4 | witu
# Processing Record 4 of Set 4 | kapit
# Processing Record 5 of Set 4 | san cristobal
# Processing Record 6 of Set 4 | gaya
# Processing Record 7 of Set 4 | abrau-dyurso
# Processing Record 8 of Set 4 | nioki
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 4 | torbay
# Processing Record 12 of Set 4 | lumut
# Processing Record 13 of Set 4 | mount gambier
# Processing Record 14 of Set 4 | geraldton
# Processing Record 15 of Set 4 | mayumba
# Processing Record 16 of Set 4 | bonavista
# Processing Record 17 of Set 4 | mahon
# Processing Record 18 of Set 4 | barabai
# Processing Record 19 of Set 4 | padang
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | carinhanha
# Processing Record 22 of Set 4 | marawi
# Processing Record 23 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 24 of Set 4 | usinsk
# Processing Record 25 of Set 4 | caldas da rainha
# Processing Record 26 of Set 4 | lompoc
# Processing Record 27 of Set 4 | sitka
# Processing Record 28 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 29 of Set 4 | saint-ambroise
# Processing Record 30 of Set 4 | vestmannaeyjar
# Processing Record 31 of Set 4 | pedernales
# Processing Record 32 of Set 4 | toora-khem
# Processing Record 33 of Set 4 | lokosovo
# Processing Record 34 of Set 4 | saint-philippe
# Processing Record 35 of Set 4 | iqaluit
# Processing Record 36 of Set 4 | noumea
# Processing Record 37 of Set 4 | te anau
# Processing Record 38 of Set 4 | ruteng
# Processing Record 39 of Set 4 | fayaoue
# Processing Record 40 of Set 4 | port elizabeth
# Processing Record 41 of Set 4 | ambulu
# Processing Record 42 of Set 4 | saint-joseph
# Processing Record 43 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 4 | daokou
# Processing Record 45 of Set 4 | lyubim
# Processing Record 46 of Set 4 | taquari
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | idrinskoye
# Processing Record 49 of Set 4 | moron
# Processing Record 50 of Set 4 | aspe
# Processing Record 1 of Set 5 | tiznit
# Processing Record 2 of Set 5 | mamontovo
# Processing Record 3 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 4 of Set 5 | arandis
# Processing Record 5 of Set 5 | kedrovyy
# Processing Record 6 of Set 5 | hamilton
# Processing Record 7 of Set 5 | harper
# Processing Record 8 of Set 5 | fairbanks
# Processing Record 9 of Set 5 | tessalit
# Processing Record 10 of Set 5 | arraial do cabo
# Processing Record 11 of Set 5 | san carlos de bariloche
# Processing Record 12 of Set 5 | kununurra
# Processing Record 13 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 5 | bundaberg
# Processing Record 15 of Set 5 | yakeshi
# Processing Record 16 of Set 5 | deputatskiy
# Processing Record 17 of Set 5 | ojinaga
# Processing Record 18 of Set 5 | banda aceh
# Processing Record 19 of Set 5 | nemuro
# Processing Record 20 of Set 5 | margate
# Processing Record 21 of Set 5 | olafsvik
# Processing Record 22 of Set 5 | houma
# Processing Record 23 of Set 5 | beidao
# Processing Record 24 of Set 5 | carnarvon
# Processing Record 25 of Set 5 | ossora
# Processing Record 26 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 5 | rio de jesus
# Processing Record 28 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 5 | ostrovnoy
# Processing Record 30 of Set 5 | rochester
# Processing Record 31 of Set 5 | westport
# Processing Record 32 of Set 5 | kruisfontein
# Processing Record 33 of Set 5 | stornoway
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | strezhevoy
# Processing Record 36 of Set 5 | hualmay
# Processing Record 37 of Set 5 | karratha
# Processing Record 38 of Set 5 | hervey bay
# Processing Record 39 of Set 5 | belaya gora
# Processing Record 40 of Set 5 | bandarbeyla
# Processing Record 41 of Set 5 | north bend
# Processing Record 42 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 5 | saldanha
# Processing Record 44 of Set 5 | maine-soroa
# Processing Record 45 of Set 5 | buraydah
# Processing Record 46 of Set 5 | klaksvik
# Processing Record 47 of Set 5 | pisco
# Processing Record 48 of Set 5 | sakakah
# Processing Record 49 of Set 5 | santa maria
# Processing Record 50 of Set 5 | constitucion
# Processing Record 1 of Set 6 | rudbar
# Processing Record 2 of Set 6 | necochea
# Processing Record 3 of Set 6 | hithadhoo
# Processing Record 4 of Set 6 | shadrinsk
# Processing Record 5 of Set 6 | saint-pierre
# Processing Record 6 of Set 6 | koungou
# Processing Record 7 of Set 6 | kudahuvadhoo
# Processing Record 8 of Set 6 | meadow lake
# Processing Record 9 of Set 6 | lahad datu
# Processing Record 10 of Set 6 | maraba
# Processing Record 11 of Set 6 | yar-sale
# Processing Record 12 of Set 6 | batticaloa
# Processing Record 13 of Set 6 | balkhash
# Processing Record 14 of Set 6 | henties bay
# Processing Record 15 of Set 6 | yueyang
# Processing Record 16 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 6 | kyren
# Processing Record 18 of Set 6 | evensk
# Processing Record 19 of Set 6 | alta floresta
# Processing Record 20 of Set 6 | dikson
# Processing Record 21 of Set 6 | mount isa
# Processing Record 22 of Set 6 | verkhniy rohachyk
# Processing Record 23 of Set 6 | sal rei
# Processing Record 24 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 6 | beyneu
# Processing Record 26 of Set 6 | encruzilhada
# Processing Record 27 of Set 6 | bud
# Processing Record 28 of Set 6 | solana beach
# Processing Record 29 of Set 6 | port hardy
# Processing Record 30 of Set 6 | catamarca
# Processing Record 31 of Set 6 | pevek
# Processing Record 32 of Set 6 | xuddur
# Processing Record 33 of Set 6 | manica
# Processing Record 34 of Set 6 | svetlaya
# Processing Record 35 of Set 6 | dunedin
# Processing Record 36 of Set 6 | quixere
# Processing Record 37 of Set 6 | carutapera
# Processing Record 38 of Set 6 | udalguri
# Processing Record 39 of Set 6 | riyadh
# Processing Record 40 of Set 6 | porto novo
# Processing Record 41 of Set 6 | beloha
# Processing Record 42 of Set 6 | vila
# Processing Record 43 of Set 6 | mount pleasant
# Processing Record 44 of Set 6 | hailar
# Processing Record 45 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 6 | georgiyevskoye
# Processing Record 47 of Set 6 | cap malheureux
# Processing Record 48 of Set 6 | cilegon
# Processing Record 49 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 50 of Set 6 | camacha
# Processing Record 1 of Set 7 | camacupa
# Processing Record 2 of Set 7 | vila velha
# Processing Record 3 of Set 7 | senador pompeu
# Processing Record 4 of Set 7 | madang
# Processing Record 5 of Set 7 | letka
# Processing Record 6 of Set 7 | waingapu
# Processing Record 7 of Set 7 | iquitos
# Processing Record 8 of Set 7 | cozumel
# Processing Record 9 of Set 7 | ponta delgada
# Processing Record 10 of Set 7 | dicabisagan
# Processing Record 11 of Set 7 | havre
# Processing Record 12 of Set 7 | pankovka
# Processing Record 13 of Set 7 | mettur
# Processing Record 14 of Set 7 | mananjary
# Processing Record 15 of Set 7 | osa
# Processing Record 16 of Set 7 | yumen
# Processing Record 17 of Set 7 | hobyo
# Processing Record 18 of Set 7 | pathein
# Processing Record 19 of Set 7 | namibe
# Processing Record 20 of Set 7 | sibolga
# Processing Record 21 of Set 7 | tura
# Processing Record 22 of Set 7 | hay river
# Processing Record 23 of Set 7 | aswan
# Processing Record 24 of Set 7 | kirensk
# Processing Record 25 of Set 7 | codrington
# Processing Record 26 of Set 7 | axim
# Processing Record 27 of Set 7 | atasu
# Processing Record 28 of Set 7 | leh
# Processing Record 29 of Set 7 | tucupita
# Processing Record 30 of Set 7 | saskylakh
# Processing Record 31 of Set 7 | tuzha
# Processing Record 32 of Set 7 | hofn
# Processing Record 33 of Set 7 | inuvik
# Processing Record 34 of Set 7 | jacareacanga
# Processing Record 35 of Set 7 | ulaangom
# Processing Record 36 of Set 7 | petropavlovka
# Processing Record 37 of Set 7 | mbulu
# Processing Record 38 of Set 7 | umm kaddadah
# Processing Record 39 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 7 | cabedelo
# Processing Record 42 of Set 7 | chongwe
# Processing Record 43 of Set 7 | traverse city
# Processing Record 44 of Set 7 | fortuna
# Processing Record 45 of Set 7 | thompson
# Processing Record 46 of Set 7 | nyurba
# Processing Record 47 of Set 7 | kologriv
# Processing Record 48 of Set 7 | chissamba
# Processing Record 49 of Set 7 | binika
# Processing Record 50 of Set 7 | muros
# Processing Record 1 of Set 8 | darque
# Processing Record 2 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 8 | vavozh
# Processing Record 4 of Set 8 | tongren
# Processing Record 5 of Set 8 | luan
# Processing Record 6 of Set 8 | cherskiy
# Processing Record 7 of Set 8 | cayenne
# Processing Record 8 of Set 8 | lardos
# Processing Record 9 of Set 8 | mangrol
# Processing Record 10 of Set 8 | amahai
# Processing Record 11 of Set 8 | lazarev
# Processing Record 12 of Set 8 | plettenberg bay
# Processing Record 13 of Set 8 | roi et
# Processing Record 14 of Set 8 | calama
# Processing Record 15 of Set 8 | duvan
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | lososina
# Processing Record 18 of Set 8 | sorland
# Processing Record 19 of Set 8 | biltine
# Processing Record 20 of Set 8 | faanui
# Processing Record 21 of Set 8 | acarau
# Processing Record 22 of Set 8 | orda
# Processing Record 23 of Set 8 | saint marys
# Processing Record 24 of Set 8 | piojo
# Processing Record 25 of Set 8 | jackson
# Processing Record 26 of Set 8 | hargeysa
# Processing Record 27 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 28 of Set 8 | pouebo
# Processing Record 29 of Set 8 | aktau
# Processing Record 30 of Set 8 | ormara
# Processing Record 31 of Set 8 | saint-louis
# Processing Record 32 of Set 8 | nouadhibou
# Processing Record 33 of Set 8 | bien hoa
# Processing Record 34 of Set 8 | khash
# Processing Record 35 of Set 8 | calbuco
# Processing Record 36 of Set 8 | awjilah
# Processing Record 37 of Set 8 | selikhino
# Processing Record 38 of Set 8 | dargaville
# Processing Record 39 of Set 8 | yulara
# Processing Record 40 of Set 8 | longyearbyen
# Processing Record 41 of Set 8 | kloulklubed
# Processing Record 42 of Set 8 | moba
# Processing Record 43 of Set 8 | talara
# Processing Record 44 of Set 8 | wani
# Processing Record 45 of Set 8 | bodden town
# Processing Record 46 of Set 8 | vila do maio
# Processing Record 47 of Set 8 | ostersund
# Processing Record 48 of Set 8 | qeshm
# Processing Record 49 of Set 8 | acajutla
# Processing Record 50 of Set 8 | shalinskoye
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | kavali
# Processing Record 3 of Set 9 | la romana
# Processing Record 4 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 9 | half moon bay
# Processing Record 6 of Set 9 | ancud
# Processing Record 7 of Set 9 | javanrud
# Processing Record 8 of Set 9 | midland
# Processing Record 9 of Set 9 | safranbolu
# Processing Record 10 of Set 9 | whitianga
# Processing Record 11 of Set 9 | iranshahr
# Processing Record 12 of Set 9 | sapa
# Processing Record 13 of Set 9 | kiunga
# Processing Record 14 of Set 9 | isangel
# Processing Record 15 of Set 9 | tokat
# Processing Record 16 of Set 9 | sobolevo
# Processing Record 17 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 9 | saint-augustin
# Processing Record 19 of Set 9 | makokou
# Processing Record 20 of Set 9 | wasilla
# Processing Record 21 of Set 9 | pangody
# Processing Record 22 of Set 9 | itambe
# Processing Record 23 of Set 9 | lakatoro
# Processing Record 24 of Set 9 | kahului
# Processing Record 25 of Set 9 | tekax
# City not found. Skipping...
# Processing Record 26 of Set 9 | thaba nchu
# Processing Record 27 of Set 9 | port blair
# Processing Record 28 of Set 9 | saint-francois
# Processing Record 29 of Set 9 | kysyl-syr
# Processing Record 30 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 31 of Set 9 | kansk
# Processing Record 32 of Set 9 | spring hill
# Processing Record 33 of Set 9 | aksu
# Processing Record 34 of Set 9 | vrangel
# Processing Record 35 of Set 9 | lhokseumawe
# Processing Record 36 of Set 9 | broome
# Processing Record 37 of Set 9 | gravelbourg
# Processing Record 38 of Set 9 | nipawin
# Processing Record 39 of Set 9 | port augusta
# Processing Record 40 of Set 9 | aksarayskiy
# Processing Record 41 of Set 9 | las vegas
# Processing Record 42 of Set 9 | san miguel
# Processing Record 43 of Set 9 | chimore
# Processing Record 44 of Set 9 | bang saphan
# Processing Record 45 of Set 9 | bage
# Processing Record 46 of Set 9 | coahuayana
# Processing Record 47 of Set 9 | chirongui
# Processing Record 48 of Set 9 | san juan
# Processing Record 49 of Set 9 | celestun
# Processing Record 50 of Set 9 | pimentel
# Processing Record 1 of Set 10 | buzmeyin
# Processing Record 2 of Set 10 | kamenka
# Processing Record 3 of Set 10 | thunder bay
# Processing Record 4 of Set 10 | linguere
# Processing Record 5 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 10 | veinticinco de mayo
# Processing Record 7 of Set 10 | upata
# Processing Record 8 of Set 10 | baculin
# Processing Record 9 of Set 10 | crestview
# Processing Record 10 of Set 10 | valparaiso
# Processing Record 11 of Set 10 | palmer
# Processing Record 12 of Set 10 | zaraza
# Processing Record 13 of Set 10 | teneguiban
# City not found. Skipping...
# Processing Record 14 of Set 10 | ixtapa
# Processing Record 15 of Set 10 | yeniseysk
# Processing Record 16 of Set 10 | marang
# Processing Record 17 of Set 10 | sioux lookout
# Processing Record 18 of Set 10 | port hedland
# Processing Record 19 of Set 10 | noshiro
# Processing Record 20 of Set 10 | santa cruz del sur
# Processing Record 21 of Set 10 | tuy hoa
# Processing Record 22 of Set 10 | el dovio
# Processing Record 23 of Set 10 | hearst
# Processing Record 24 of Set 10 | maragogi
# Processing Record 25 of Set 10 | rio claro
# Processing Record 26 of Set 10 | nouakchott
# Processing Record 27 of Set 10 | moose factory
# Processing Record 28 of Set 10 | yunyang
# Processing Record 29 of Set 10 | mana
# Processing Record 30 of Set 10 | dingzhou
# Processing Record 31 of Set 10 | lakewood
# Processing Record 32 of Set 10 | sawtell
# Processing Record 33 of Set 10 | mocuba
# Processing Record 34 of Set 10 | tres arroyos
# Processing Record 35 of Set 10 | diamantina
# Processing Record 36 of Set 10 | tual
# Processing Record 37 of Set 10 | tairua
# Processing Record 38 of Set 10 | batemans bay
# Processing Record 39 of Set 10 | poya
# Processing Record 40 of Set 10 | taoudenni
# Processing Record 41 of Set 10 | buin
# Processing Record 42 of Set 10 | princeton
# Processing Record 43 of Set 10 | de aar
# Processing Record 44 of Set 10 | eyl
# Processing Record 45 of Set 10 | khuzhir
# Processing Record 46 of Set 10 | roald
# Processing Record 47 of Set 10 | itarema
# Processing Record 48 of Set 10 | bousso
# Processing Record 49 of Set 10 | firovo
# Processing Record 50 of Set 10 | amurrio
# Processing Record 1 of Set 11 | caravelas
# Processing Record 2 of Set 11 | shingu
# Processing Record 3 of Set 11 | zaltan
# Processing Record 4 of Set 11 | hashtgerd
# Processing Record 5 of Set 11 | manubul
# Processing Record 6 of Set 11 | makakilo city
# Processing Record 7 of Set 11 | naron
# Processing Record 8 of Set 11 | omsukchan
# Processing Record 9 of Set 11 | zhigansk
# Processing Record 10 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 11 | aklavik
# Processing Record 12 of Set 11 | homa bay
# Processing Record 13 of Set 11 | thinadhoo
# Processing Record 14 of Set 11 | egvekinot
# Processing Record 15 of Set 11 | snyder
# Processing Record 16 of Set 11 | sinnamary
# Processing Record 17 of Set 11 | talnakh
# Processing Record 18 of Set 11 | tiarei
# Processing Record 19 of Set 11 | montepuez
# Processing Record 20 of Set 11 | skibbereen
# Processing Record 21 of Set 11 | hami
# Processing Record 22 of Set 11 | ullubiyaul
# Processing Record 23 of Set 11 | mizdah
# Processing Record 24 of Set 11 | banjarmasin
# Processing Record 25 of Set 11 | terrace
# Processing Record 26 of Set 11 | havre-saint-pierre
# Processing Record 27 of Set 11 | port-gentil
# Processing Record 28 of Set 11 | sumbe
# Processing Record 29 of Set 11 | didwana
# Processing Record 30 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 31 of Set 11 | rio gallegos
# Processing Record 32 of Set 11 | zafra
# Processing Record 33 of Set 11 | puerto cabezas
# Processing Record 34 of Set 11 | uren
# Processing Record 35 of Set 11 | morgan city
# Processing Record 36 of Set 11 | vestmanna
# Processing Record 37 of Set 11 | andrews
# Processing Record 38 of Set 11 | knysna
# Processing Record 39 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 11 | unai
# Processing Record 41 of Set 11 | vardo
# Processing Record 42 of Set 11 | avera
# Processing Record 43 of Set 11 | burgeo
# Processing Record 44 of Set 11 | fulitun
# City not found. Skipping...
# Processing Record 45 of Set 11 | salinas
# Processing Record 46 of Set 11 | kolpny
# Processing Record 47 of Set 11 | kaitangata
# Processing Record 48 of Set 11 | tarko-sale
# Processing Record 49 of Set 11 | toribio
# Processing Record 50 of Set 11 | peace river
# Processing Record 1 of Set 12 | glebychevo
# Processing Record 2 of Set 12 | xanxere
# Processing Record 3 of Set 12 | tautira
# Processing Record 4 of Set 12 | zbarazh
# Processing Record 5 of Set 12 | pangnirtung
# Processing Record 6 of Set 12 | vagiulesti
# Processing Record 7 of Set 12 | vanimo
# Processing Record 8 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 9 of Set 12 | nara
# Processing Record 10 of Set 12 | bay roberts
# Processing Record 11 of Set 12 | sierra vista
# Processing Record 12 of Set 12 | gurgentepe
# Processing Record 13 of Set 12 | naryan-mar
# Processing Record 14 of Set 12 | erenhot
# Processing Record 15 of Set 12 | honiara
# Processing Record 16 of Set 12 | general roca
# Processing Record 17 of Set 12 | pierre
# Processing Record 18 of Set 12 | saint anthony
# Processing Record 19 of Set 12 | loreto
# Processing Record 20 of Set 12 | culebra
# Processing Record 21 of Set 12 | vila franca do campo
# Processing Record 22 of Set 12 | panjab
# Processing Record 23 of Set 12 | la asuncion
# Processing Record 24 of Set 12 | kindu
# Processing Record 25 of Set 12 | kovrov
# Processing Record 26 of Set 12 | anshun
# Processing Record 27 of Set 12 | severodvinsk
# Processing Record 28 of Set 12 | calella
# Processing Record 29 of Set 12 | tabas
# Processing Record 30 of Set 12 | aranos
# Processing Record 31 of Set 12 | nome
# Processing Record 32 of Set 12 | lasa
# Processing Record 33 of Set 12 | samaipata
# Processing Record 34 of Set 12 | mughal sarai
# Processing Record 35 of Set 12 | monrovia
# Processing Record 36 of Set 12 | cuenca
# Processing Record 37 of Set 12 | fernley
# Processing Record 38 of Set 12 | swellendam
# Processing Record 39 of Set 12 | mandali
# Processing Record 40 of Set 12 | cairns
# Processing Record 41 of Set 12 | yatou
# Processing Record 42 of Set 12 | alofi
# Processing Record 43 of Set 12 | ullapool
# Processing Record 44 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 12 | maldonado
# Processing Record 46 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 47 of Set 12 | caraballeda
# Processing Record 48 of Set 12 | nizwa
# Processing Record 49 of Set 12 | reshetnikovo
# Processing Record 50 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 13 | kletskaya
# Processing Record 2 of Set 13 | pattani
# Processing Record 3 of Set 13 | makurdi
# Processing Record 4 of Set 13 | puri
# Processing Record 5 of Set 13 | quimper
# Processing Record 6 of Set 13 | san bartolome de tirajana
# Processing Record 7 of Set 13 | kavaratti
# Processing Record 8 of Set 13 | burica
# City not found. Skipping...
# Processing Record 9 of Set 13 | kardailovo
# Processing Record 10 of Set 13 | hirara
# Processing Record 11 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 13 | smolenka
# Processing Record 13 of Set 13 | makubetsu
# Processing Record 14 of Set 13 | hongjiang
# Processing Record 15 of Set 13 | taltal
# Processing Record 16 of Set 13 | tashtyp
# Processing Record 17 of Set 13 | skage
# City not found. Skipping...
# Processing Record 18 of Set 13 | cuamba
# Processing Record 19 of Set 13 | kyabe
# Processing Record 20 of Set 13 | ende
# Processing Record 21 of Set 13 | qasigiannguit
# Processing Record 22 of Set 13 | sergeyevka
# Processing Record 23 of Set 13 | kailua
# Processing Record 24 of Set 13 | helong
# Processing Record 25 of Set 13 | sapao
# City not found. Skipping...
# Processing Record 26 of Set 13 | dongsheng
# Processing Record 27 of Set 13 | mantsala
# Processing Record 28 of Set 13 | dali
# Processing Record 29 of Set 13 | udachnyy
# Processing Record 30 of Set 13 | khorixas
# Processing Record 31 of Set 13 | summerland
# Processing Record 32 of Set 13 | baruun-urt
# Processing Record 33 of Set 13 | les herbiers
# Processing Record 34 of Set 13 | fort abbas
# Processing Record 35 of Set 13 | yuancheng
# Processing Record 36 of Set 13 | pemangkat
# Processing Record 37 of Set 13 | zurrieq
# Processing Record 38 of Set 13 | magdagachi
# Processing Record 39 of Set 13 | djibo
# Processing Record 40 of Set 13 | imeni zhelyabova
# Processing Record 41 of Set 13 | oranjemund
# Processing Record 42 of Set 13 | meulaboh
# Processing Record 43 of Set 13 | lyman
# Processing Record 44 of Set 13 | mouzakion
# City not found. Skipping...
# Processing Record 45 of Set 13 | bonthe
# Processing Record 46 of Set 13 | college
# Processing Record 47 of Set 13 | luwuk
# Processing Record 48 of Set 13 | dudinka
# Processing Record 49 of Set 13 | ati
# Processing Record 50 of Set 13 | kosa
# Processing Record 1 of Set 14 | pacific grove
# Processing Record 2 of Set 14 | paternion
# Processing Record 3 of Set 14 | talcahuano
# Processing Record 4 of Set 14 | dakar
# Processing Record 5 of Set 14 | vao
# Processing Record 6 of Set 14 | tamiahua
# Processing Record 7 of Set 14 | sergiyevsk
# Processing Record 8 of Set 14 | hillsborough
# Processing Record 9 of Set 14 | mpwapwa
# Processing Record 10 of Set 14 | maun
# Processing Record 11 of Set 14 | san andres
# Processing Record 12 of Set 14 | pangoa
# Processing Record 13 of Set 14 | gweta
# Processing Record 14 of Set 14 | palu
# Processing Record 15 of Set 14 | ust-karsk
# Processing Record 16 of Set 14 | kenai
# Processing Record 17 of Set 14 | nador
# Processing Record 18 of Set 14 | berbera
# Processing Record 19 of Set 14 | audru
# Processing Record 20 of Set 14 | magadan
# Processing Record 21 of Set 14 | kontagora
# Processing Record 22 of Set 14 | trollhattan
# Processing Record 23 of Set 14 | giyon
# Processing Record 24 of Set 14 | kang
# Processing Record 25 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 26 of Set 14 | kupang
# Processing Record 27 of Set 14 | sao miguel do araguaia
# Processing Record 28 of Set 14 | shinpokh
# Processing Record 29 of Set 14 | marsa matruh
# Processing Record 30 of Set 14 | liwale
# Processing Record 31 of Set 14 | tudela
# Processing Record 32 of Set 14 | flin flon
# Processing Record 33 of Set 14 | inongo
# Processing Record 34 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 14 | arlit
# Processing Record 36 of Set 14 | statesboro
# Processing Record 37 of Set 14 | manadhoo
# Processing Record 38 of Set 14 | opuwo
# Processing Record 39 of Set 14 | barabinsk
# Processing Record 40 of Set 14 | kisangani
# Processing Record 41 of Set 14 | basco
# Processing Record 42 of Set 14 | skjervoy
# Processing Record 43 of Set 14 | san policarpo
# Processing Record 44 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 14 | abu kamal
# Processing Record 46 of Set 14 | bengkulu
# Processing Record 47 of Set 14 | floresta
# Processing Record 48 of Set 14 | jutai
# Processing Record 49 of Set 14 | sovetskiy
# Processing Record 50 of Set 14 | paita
# Processing Record 1 of Set 15 | tignere
# Processing Record 2 of Set 15 | puerto carreno
# Processing Record 3 of Set 15 | impfondo
# Processing Record 4 of Set 15 | beringovskiy
# Processing Record 5 of Set 15 | mega
# Processing Record 6 of Set 15 | lavrentiya
# Processing Record 7 of Set 15 | taitung
# Processing Record 8 of Set 15 | bar harbor
# Processing Record 9 of Set 15 | richards bay
# Processing Record 10 of Set 15 | bahia blanca
# Processing Record 11 of Set 15 | parras
# City not found. Skipping...
# Processing Record 12 of Set 15 | guane
# Processing Record 13 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 15 | lakeway
# Processing Record 15 of Set 15 | jega
# Processing Record 16 of Set 15 | babstovo
# Processing Record 17 of Set 15 | ugoofaaru
# Processing Record 18 of Set 15 | bilibino
# Processing Record 19 of Set 15 | los llanos de aridane
# Processing Record 20 of Set 15 | losal
# Processing Record 21 of Set 15 | jasper
# Processing Record 22 of Set 15 | portoferraio
# Processing Record 23 of Set 15 | wajid
# Processing Record 24 of Set 15 | mandan
# Processing Record 25 of Set 15 | nanakuli
# Processing Record 26 of Set 15 | coolum beach
# Processing Record 27 of Set 15 | cedar city
# Processing Record 28 of Set 15 | xiongshi
# City not found. Skipping...
# Processing Record 29 of Set 15 | mwadui
# Processing Record 30 of Set 15 | aliwal north
# Processing Record 31 of Set 15 | mendi
# Processing Record 32 of Set 15 | pudozh
# Processing Record 33 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 34 of Set 15 | fare
# Processing Record 35 of Set 15 | chumikan
# Processing Record 36 of Set 15 | kizema
# Processing Record 37 of Set 15 | kharitonovo
# Processing Record 38 of Set 15 | sagaing
# Processing Record 39 of Set 15 | iki-burul
# Processing Record 40 of Set 15 | urumqi
# Processing Record 41 of Set 15 | zapolyarnyy
# Processing Record 42 of Set 15 | kalga
# Processing Record 43 of Set 15 | stephenville
# Processing Record 44 of Set 15 | yerazgavors
# Processing Record 45 of Set 15 | narsaq
# Processing Record 46 of Set 15 | sarankhola
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Jamestown      US  42.10  -79.24     73.99        81         100
# 1       Albany      US  42.60  -73.97     91.99        35          87
# 2  Port Alfred      ZA -33.59   26.89     59.65        75           0
# 3       Sokoni      TZ  -6.43   39.55     76.01        81           0
# 4     Hermanus      ZA -34.42   19.23     55.99        87           0
# 5   Butaritari      KI   3.07  172.79     83.53        78           6
# 6    Busselton      AU -33.65  115.33     51.01        81          94
# 7        Kumla      SE  59.13   15.14     68.00        64          22
# 8       Rawson      AR -43.30  -65.10     59.92        38          73
# 9        Adrar      MR  20.50  -10.07    104.23        11           3
#
#    Wind Speed Curent Description
# 0        5.99         light rain
# 1        1.97    overcast clouds
# 2        8.77          clear sky
# 3       18.23          clear sky
# 4        7.00          clear sky
# 5       15.43          clear sky
# 6        1.12    overcast clouds
# 7        3.36         few clouds
# 8       19.91      broken clouds
# 9       10.80          clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
